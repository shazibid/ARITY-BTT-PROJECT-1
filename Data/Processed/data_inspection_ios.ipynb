# %%
import pandas as pd
import numpy as np
import os

# %%
# Load data into data frame
filename = os.path.join(os.getcwd(), "ios_turns.csv")
df = pd.read_csv(filename, header = 0)

# %%
df.describe()
# Out:
# /Users/shazi/Library/Python/3.12/lib/python/site-packages/numpy/_core/_methods.py:51: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#           init_time  eventAction  payloadCreation    eventStart      eventEnd  \
# count  6.109400e+04      61094.0          61094.0  6.109400e+04  6.109400e+04
# mean   1.720234e+12          1.0              1.0  1.094169e+06  1.099123e+06
# std    8.282511e+09          0.0              0.0  2.183122e+06  2.183208e+06
# min    1.702584e+12          1.0              1.0  2.952144e+03  4.847230e+03
# 25%    1.712613e+12          1.0              1.0  2.249281e+05  2.298995e+05
# 50%    1.721009e+12          1.0              1.0  5.614414e+05  5.665474e+05
# 75%    1.726888e+12          1.0              1.0  1.253427e+06  1.258467e+06
# max    1.736258e+12          1.0              1.0  6.362140e+07  6.363137e+07
#
# ...

# %%
df.shape
# Out:
# (61094, 34)

# %%
df.columns.tolist()
# Out:
# ['init_time',
#  'eventAction',
#  'payloadCreation',
#  'eventStart',
#  'eventEnd',
#  'eventType',
#  'eventSampleSpeed',
#  'eventDurationSeconds',
#  'eventMilesDriven',
#  'eventStartLatitude',
#  'eventStartLongitude',
#  'eventEndLatitude',
#  'eventEndLongitude',
#  'eventSensorDetectionMthd',
#  'eventGPSSignalStrength',
#  'eventStartSpeed',
#  'eventEndSpeed',
#  'eventSpeedChange',
#  'memsMedianLateralAccel',
#  'memsP75LateralAccel',
#  'memsP95LateralAccel',
#  'memsMedianHorizontalNorm',
#  'memsP75HorizontalNorm',
#  'memsP95HorizontalNorm',
#  'gpsMedianLateralAccel',
#  'gpsP75LateralAccel',
#  'gpsP95LateralAccel',
#  'bearing_angular_change_per_second',
#  'gyro_angular_change_per_second',
#  'bearingAngleChange',
#  'gyroAngleChange',
#  'mems_radius',
#  'gps_radius',
#  'validity_mean']

# %%
df.head()
# Out:
#       init_time  eventAction  payloadCreation  eventStart   eventEnd  \
# 0  1.713042e+12          1.0              1.0   479553.47  484875.20
# 1  1.713042e+12          1.0              1.0   459179.94  464064.80
# 2  1.713042e+12          1.0              1.0   448020.16  456677.90
# 3  1.713042e+12          1.0              1.0   427011.25  434835.00
# 4  1.713042e+12          1.0              1.0   395398.60  402547.22
#
#    eventType  eventSampleSpeed  eventDurationSeconds  eventMilesDriven  \
# 0        4.0          8.553064              5.321719          0.014196
# 1        4.0          9.360758              4.884875          0.012575
# 2        5.0         10.681455              8.657750          0.021795
# 3        5.0         10.399240              7.823751          0.016130
# 4        4.0          8.345368              7.148625          0.017785
#
#    eventStartLatitude  ...  gpsMedianLateralAccel  gpsP75LateralAccel  \
# ...

# %%
df = df.drop('eventAction', axis = 1).drop('payloadCreation', axis = 1)
df.columns.tolist()
# Out:
# ['init_time',
#  'eventStart',
#  'eventEnd',
#  'eventType',
#  'eventSampleSpeed',
#  'eventDurationSeconds',
#  'eventMilesDriven',
#  'eventStartLatitude',
#  'eventStartLongitude',
#  'eventEndLatitude',
#  'eventEndLongitude',
#  'eventSensorDetectionMthd',
#  'eventGPSSignalStrength',
#  'eventStartSpeed',
#  'eventEndSpeed',
#  'eventSpeedChange',
#  'memsMedianLateralAccel',
#  'memsP75LateralAccel',
#  'memsP95LateralAccel',
#  'memsMedianHorizontalNorm',
#  'memsP75HorizontalNorm',
#  'memsP95HorizontalNorm',
#  'gpsMedianLateralAccel',
#  'gpsP75LateralAccel',
#  'gpsP95LateralAccel',
#  'bearing_angular_change_per_second',
#  'gyro_angular_change_per_second',
#  'bearingAngleChange',
#  'gyroAngleChange',
#  'mems_radius',
#  'gps_radius',
#  'validity_mean']

# %%
#building data frame 1: state 0 of eventSenesorDetectionMthd
#required features:
