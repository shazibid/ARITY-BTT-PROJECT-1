# %%
import numpy as np
import pandas as pd
import os 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import hdbscan

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score

# %%
df = pd.read_pickle('../../data/processed/merged/state0_new_df.pkl')
print(df.shape)
# Out:
# (45993, 15)

# %%
df = df[(df['eventType'] == 4) & (df['is_ios'] == 0)]

df = df.drop(columns=['is_ios', 'eventType', 'eventSampleSpeed', 'eventGPSSignalStrength', 'eventSensorDetectionMthd', 'source_file', 'gpsP75LateralAccel', 'gpsP95LateralAccel'])
df = df.dropna(subset=['bearingAngleChange'])
corr_matrix = df.corr()

# %%
df.columns
# Out:
# Index(['eventDurationSeconds', 'eventStartSpeed', 'eventEndSpeed',
#        'gpsMedianLateralAccel', 'bearing_angular_change_per_second',
#        'bearingAngleChange', 'gps_radius'],
#       dtype='object')

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(df)

# %%
clusterer = hdbscan.HDBSCAN()

# %%
clusterer.fit(df)
# Out:
# /Users/connieyang/Documents/GitHub/ARITY-BTT-PROJECT-1/.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/connieyang/Documents/GitHub/ARITY-BTT-PROJECT-1/.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# HDBSCAN()

# %%
clusterer.labels_
# Out:
# array([ 3,  3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,  3,
#         3,  3,  3,  3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  0,  3,  2,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3, -1,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  1,  3,  3,  3, -1,  3,  3,  3,  3,
#         0,  3,  3,  3,  3,  3,  1, -1,  3, -1,  3,  3,  3, -1,  3,  3,  0,
#         3,  3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3, -1,  3, -1,  2,  3,  3,  3,  3,  3,  0,  3, -1, -1,
#         3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  0,
#         3,  3,  3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  0,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  0,  3,  3, -1, -1, -1,  3,  1,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3, -1,  3,  3,  3,  3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,
#         3,  3, -1,  3,  3,  3,  3,  3, -1, -1,  3, -1,  3,  3,  3, -1,  3,
#         3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,
#         3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         1,  2,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,
#         3,  0,  3,  3,  3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  2,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,  3,  3,  3,  2,
#         3,  3,  3, -1,  3,  3,  0,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1, -1,
#         3,  3,  0,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3, -1,  3,  3,  1,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  2,  3,  3,  3, -1,  3,  0,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3, -1,  3,  3,  3,  3, -1,  3,  3, -1,
#         3,  3, -1, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3, -1,  3,  3, -1, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3, -1,  3,  3,  3,  3,  3,  3,  3,  3,  3, -1,  3,  3,  3,
#         3])

# %%
clusterer.labels_.max()
# Out:
# np.int64(3)

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=clusterer.labels_, s=10)
plt.title("HDBSCAN Clusters (3D PCA Projection)")
plt.show()

# %%
df['cluster']   = clusterer.labels_
df.head()
# Out:
#     eventDurationSeconds  eventStartSpeed  eventEndSpeed  \
# 0               7.244125        17.323687       6.789408
# 1               7.497719         6.197542      10.101060
# 6               3.947750        12.242492      14.028724
# 9               5.356430        22.033857      18.588970
# 11              4.999106         9.439885      24.069471
#
#     gpsMedianLateralAccel  bearing_angular_change_per_second  \
# 0                0.738191                           8.662511
# 1                0.926223                           9.708605
# 6                1.762359                          18.826092
# 9                2.415130                          16.410183
# 11               2.707142                          17.183073
#
#     bearingAngleChange  gps_radius  cluster
# 0            67.596880   20.335337        3
# 1            80.071320   21.819538        3
# 6            82.983246   16.224472        3
# 9            88.200966   31.072239        3
# 11          157.401670   19.227425       -1

# %%
df.groupby('cluster').mean()
# Out:
#          eventDurationSeconds  eventStartSpeed  eventEndSpeed  \
# cluster
# -1                   6.644057        18.564042      18.900839
#  0                  12.937633        43.758378      45.348952
#  1                   6.262796         6.570867      11.546585
#  2                   9.176787        28.923123      27.728848
#  3                   4.790947        11.783803      15.749772
#
#          gpsMedianLateralAccel  bearing_angular_change_per_second  \
# cluster
# -1                    1.660135                          13.013794
#  0                    2.415672                           6.780627
#  1                    1.717630                          21.744078
#  2                    1.524904                           6.182797
#  3                    1.619596                          14.273341
#
#          bearingAngleChange  gps_radius
# cluster
# -1                82.379081   60.086280
#  0                91.376627  151.685323
#  1               166.146780   10.214364
#  2                62.081623   93.676827
#  3                72.586658   25.841529

# %%
df['probability'] = clusterer.probabilities_
print(df.groupby('cluster')['probability'].mean())

sns.boxplot(x='cluster', y='probability', data=df)
plt.title("Cluster Membership Confidence")
plt.show()
# Out:
# cluster
# -1    0.000000
#  0    0.782077
#  1    1.000000
#  2    0.988273
#  3    0.949018
# Name: probability, dtype: float64

# %%
df['cluster'].value_counts()
# Out:
# cluster
#  3    470
# -1     46
#  0     18
#  2      6
#  1      5
# Name: count, dtype: int64

# %%
mask = clusterer.labels_ != -1
score = silhouette_score(X_scaled[mask], clusterer.labels_[mask])
print("Silhouette Score (excluding noise):", score)
# Out:
# Silhouette Score (excluding noise): 0.365407228592472
