# %%
from pathlib import Path
import pandas as pd
import os 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score

# %%
here = Path.cwd()
root = next(p for p in [here, *here.parents] if (p / "data" / "processed").exists())

#creating 2 columns to identify source file and if ios or android
df_android = pd.read_csv(root / "data" / "processed" / "android" / "parent_clean.csv", header=0)
df_android.head()
# Out:
#    is_ios        source_file  eventType  eventSampleSpeed  \
# 0       0  android_turns.csv        4.0         10.394929
# 1       0  android_turns.csv        4.0          9.401910
# 2       0  android_turns.csv        5.0         11.290954
# 3       0  android_turns.csv        5.0         12.743101
# 4       0  android_turns.csv        5.0          8.986107
#
#    eventDurationSeconds  eventMilesDriven  eventSensorDetectionMthd  \
# 0              7.244125          0.016991                       2.0
# 1              7.497719          0.016103                       2.0
# 2              4.244563          0.008359                       2.0
# 3              3.173500          0.007654                       1.0
# 4              5.990321          0.013587                       0.0
#
#    eventGPSSignalStrength  eventStartSpeed  eventEndSpeed  ...  \
# 0                1.480796        17.323687       6.789408  ...
# 1                1.693853         6.197542      10.101060  ...
# 2               21.173470        11.229438       9.081976  ...
# 3               15.306123        10.714942      13.421639  ...
# 4               19.387754         2.729067      20.937756  ...
#
#    gpsP75LateralAccel  gpsP95LateralAccel  bearing_angular_change_per_second  \
# 0            0.800598            0.854956                           8.662511
# 1            1.051501            1.147173                           9.708605
# 2            1.494703            1.494703                          11.732657
# 3            1.770240            1.770240                          10.335592
# 4            1.698927            2.619599                          11.501888
#
#    gyro_angular_change_per_second  bearingAngleChange  gyroAngleChange  \
# 0                        9.521707           67.596880        69.319600
# 1                       11.245602           80.071320        84.723694
# 2                       24.616348           44.000920       105.462135
# 3                       17.929585           45.601433        57.610783
# 4                        2.787075           74.401410        16.806042
#
#    mems_radius  gps_radius  speed_gap  aggressive
# 0    22.941639   20.335337 -10.534279           0
# 1    20.737572   21.819538   3.903518           0
# 2    18.996666   29.467962  -2.147462           0
# 3    23.959110   21.440578   2.706697           0
# 4    91.713660   12.708904  18.208689           0
#
# [5 rows x 27 columns]

# %%
df_android['is_ios'].sum() #checking for no ios data
# Out:
# np.int64(0)

# %%
# eventType = 4 for turning left, eventType = 5 for turning right
# is_ios = 0 for Android, is_ios = 1 for iOS

sub_df_left = df_android[df_android['eventType'] == 4]
sub_df_right = df_android[df_android['eventType'] == 5]

# %%
sub_df_left.shape
# Out:
# (546, 27)

# %%
features_to_plot = [
    'eventDurationSeconds',
    'eventMilesDriven',
    'eventStartSpeed',
    'eventEndSpeed',
    #'eventSpeedChange',
    'memsMedianHorizontalNorm',
    'gyro_angular_change_per_second',
    'gyroAngleChange',
    'mems_radius'
]

# Standardize data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(sub_df_right[features_to_plot])

scaled_df = pd.DataFrame(scaled_data, columns=features_to_plot)

# %%
# Use elbow method to get optimal number of clusters
wcss = []
k_range = range(1, 11) 

for k in k_range:
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_range, wcss, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS (Inertia)')
plt.show()

# %%
#performance metric to look at cluster quality 
results = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(scaled_df)
    labels = kmeans.labels_
    
    sil_score = silhouette_score(scaled_df, labels)
    ch_score = calinski_harabasz_score(scaled_df, labels)
    
    results.append({
        'k': k,
        'Silhouette Score': sil_score,
        'Calinski-Harabasz Score': ch_score
    })
    
    scaled_df_clustered = scaled_df.copy()
    scaled_df_clustered['klabel'] = labels

results_df = pd.DataFrame(results)
display(results_df)

plt.figure(figsize=(7, 5))
plt.plot(results_df['k'], results_df['Calinski-Harabasz Score'], marker='o', label='Calinski-Harabasz')
plt.title('K-Means Evaluation Metrics')
plt.xlabel('Number of Clusters (k)')
plt.legend()
plt.show()

plt.figure(figsize=(7, 5))
plt.plot(results_df['k'], results_df['Silhouette Score'], marker='o', label='Silhouette')
plt.title('K-Means Evaluation Metrics')
plt.xlabel('Number of Clusters (k)')
plt.legend()
plt.show()
# Out:
#     k  Silhouette Score  Calinski-Harabasz Score
# 0   2          0.434265               193.169345
# 1   3          0.434367               171.195398
# 2   4          0.363513               190.188495
# 3   5          0.234309               167.269065
# 4   6          0.364461               227.049965
# 5   7          0.280865               222.247916
# 6   8          0.222658               185.530658
# 7   9          0.244641               203.661444
# 8  10          0.215635               194.207423

# %%
kmeans_final = KMeans(n_clusters=3, n_init=10)
kmeans_final.fit(scaled_df)
final_labels = kmeans_final.labels_

pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
pca_df['Cluster_Label'] = final_labels

cluster_centers_pca = pca.transform(kmeans_final.cluster_centers_)

plt.figure(figsize=(10, 8))
sns.scatterplot(
    x='PC1', 
    y='PC2', 
    hue='Cluster_Label',
    data=pca_df, 
    palette='Set1',
    alpha=0.6,
    s=25
)

plt.title('K-Means Cluster Visualization (k=2) via PC')
plt.xlabel(f'PC 1')
plt.ylabel(f'PC 2')
plt.legend(title='Cluster')
plt.show()
# Out:
# c:\Users\kllyp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
kmeans_final = KMeans(n_clusters=3, n_init=10) 
kmeans_final.fit(scaled_df)
final_labels = kmeans_final.labels_

df_clustered = sub_df_right.copy()

# %%
df_clustered['Cluster_Label'] = final_labels
df_clustered['Cluster_Label'] = df_clustered['Cluster_Label'].astype('category')

df_melted = df_clustered[['Cluster_Label'] + features_to_plot].melt(
    id_vars=['Cluster_Label'],
    var_name='Feature',
    value_name='Value'
)

sns.set_style("whitegrid")
g = sns.catplot(
    data=df_melted,
    x='Cluster_Label',
    y='Value',
    col='Feature',
    kind='box', 
    col_wrap=3, 
    palette='Set1',
    sharey=False,
    height=3.5,
    aspect=1.2  
)

g.fig.suptitle('Android Right Turns Feature Distributions by Cluster (k=3)', y=1.02, fontsize=16)
g.set_titles("Feature: {col_name}", size=12)
g.set_axis_labels("Cluster Label", "Feature Value (Original Scale)", size=10) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kllyp\AppData\Local\Temp\ipykernel_31076\832302993.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(

# %%
pca_3d = PCA(n_components=3)
pca_resulpca_3d = PCA(n_components=3)
pca_result = pca_3d.fit_transform(scaled_df)

kmeans_3d = KMeans(n_clusters=3, n_init=10)
labels_3d = kmeans_3d.fit_predict(pca_result)
t = pca_3d.fit_transform(scaled_df)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(
    pca_result[:, 0], pca_result[:, 1], pca_result[:, 2],
    c=labels_3d, cmap='viridis', s=40, alpha=0.7
)
#cmap='viridis' sets the color palette
#s=40 sets the size of each point
#alpha=0.7 makes the points slightly transparent

ax.set_title('3D PCA Visualization of K-Means Clusters')
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('PCA 3')

# Legend
legend_labels = ['Cluster 0', 'Cluster 1', 'Cluster 2']
legend_colors = [scatter.cmap(scatter.norm(i)) for i in range(3)]
for label, color in zip(legend_labels, legend_colors):
    ax.scatter([], [], [], c=[color], label=label)
ax.legend(title='Cluster')

plt.show()
